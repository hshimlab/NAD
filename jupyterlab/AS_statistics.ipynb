# %% [markdown]
# ## Calculate statistics from Adaptive Sampling files generated by Nanopore
# ### Author: Hyunjin Shim
# ### Date: 2023.10.15

# %%
#Science and Data
import csv
import pandas as pd
import numpy as np

# Infrastructure
from pathlib import Path
import sys
import os

#Plotting Tools
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# files
f1 = 'data/AS/AS_P_aeruginosa_1.csv'
f2 = 'data/AS/AS_P_aeruginosa_2.csv'
f3 = 'data/AS/AS_Salmonella_1.csv'
f4 = 'data/AS/AS_Salmonella_2.csv'
f5 = 'data/AS/AS_Salmonella_3.csv'

# %%
# csv to dataframe
P_aeruginosa_1 = pd.read_csv (f1)
P_aeruginosa_2 = pd.read_csv (f2)
Salmonella_1 = pd.read_csv (f3)
Salmonella_2 = pd.read_csv (f4)
Salmonella_3 = pd.read_csv (f5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/g8/ndl7f2qj4sx86gykyblzf7cm0000gn/T/ipykernel_72469/1845096735.py in <module>
#       1 # csv to dataframe
# ----> 2 P_aeruginosa_1 = pd.read_csv (f1)
#       3 P_aeruginosa_2 = pd.read_csv (f2)
#       4 Salmonella_1 = pd.read_csv (f3)
#       5 Salmonella_2 = pd.read_csv (f4)
#
# ...

# %%
# count AS decision types
P_aeruginosa_1['decision'].value_counts()
# Out:
# unblock           1034891
# no_decision        904914
# stop_receiving      52348
# Name: decision, dtype: int64

# %%
Salmonella_1['sequence_length']['decision']

# %%
# Create bars
plt.bar(3, Salmonella_1['sequence_length'])

# Create names on the x-axis
plt.xticks(3, Salmonella_1['decision'])

# Show graphic
plt.show()
